# %% [markdown]
# # Tf-idf + Linear SVC (Baseline)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, f1_score
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC

# %%
df = pd.read_csv("../data/raw_data.csv").drop(columns=["Publish Date"])
df
# Out:
#                                                    Title  \
# 0      Estimating the J function without edge correction
# 1      Is Bootstrap Really Helpful in Point Process S...
# 2                    Reconstruction of Gray-scale Images
# 3                                 Algorithmic Statistics
# 4      Minimax Entropy and Maximum Likelihood. Comple...
# ...                                                  ...
# 60749  A stochastic optimisation unadjusted Langevin ...
# 60750  Estimating hidden population size from a singl...
# 60751       Repelling-Attracting Hamiltonian Monte Carlo
# 60752  Simultaneous Conformal Prediction of Missing O...
# 60753  Bayesian Inference of Time-Varying Origin-Dest...
#
#                                                 Abstract Primary Category
# 0      The interaction between points in a spatial po...          stat.TH
# 1      There are some papers which describe the use o...          stat.TH
# 2      Reconstruction of images corrupted by noise is...          stat.TH
# 3      While Kolmogorov complexity is the accepted ab...          stat.TH
# 4      Concept of exponential family is generalized b...          stat.TH
# ...                                                  ...              ...
# 60749  This paper presents a novel stochastic optimis...          stat.AP
# 60750  This work is concerned with the estimation of ...          stat.ME
# 60751  We propose a variant of Hamiltonian Monte Carl...          stat.TH
# 60752  We study the problem of simultaneous predictiv...          stat.ME
# 60753  Origin-destination (OD) demand matrices are cr...          stat.AP
#
# [60754 rows x 3 columns]

# %%
df["Text"] = df["Title"] + "\n\n" + df["Abstract"]
df = df.drop(columns=["Title", "Abstract"])
df
# Out:
#       Primary Category                                               Text
# 0              stat.TH  Estimating the J function without edge correct...
# 1              stat.TH  Is Bootstrap Really Helpful in Point Process S...
# 2              stat.TH  Reconstruction of Gray-scale Images\n\nReconst...
# 3              stat.TH  Algorithmic Statistics\n\nWhile Kolmogorov com...
# 4              stat.TH  Minimax Entropy and Maximum Likelihood. Comple...
# ...                ...                                                ...
# 60749          stat.AP  A stochastic optimisation unadjusted Langevin ...
# 60750          stat.ME  Estimating hidden population size from a singl...
# 60751          stat.TH  Repelling-Attracting Hamiltonian Monte Carlo\n...
# 60752          stat.ME  Simultaneous Conformal Prediction of Missing O...
# 60753          stat.AP  Bayesian Inference of Time-Varying Origin-Dest...
#
# [60754 rows x 2 columns]

# %%
print(df["Text"].iloc[477])
# Out:
# Laws and Likelihoods for Ornstein Uhlenbeck-Gamma and other BNS OU Stochastic Volatilty models with extensions
#
# In recent years there have been many proposals as flexible alternatives to
# Gaussian based continuous time stochastic volatility models. A great deal of
# these models employ positive L\'evy processes. Among these are the attractive
# non-Gaussian positive Ornstein-Uhlenbeck (OU) processes proposed by
# Barndorff-Nielsen and Shephard (BNS) in a series of papers. One current problem
# of these approaches is the unavailability of a tractable likelihood based
# statistical analysis for the returns of financial assets. This paper, while
# focusing on the BNS models, develops general theory for the implementation of
# statistical inference for a host of models. Specifically we show how to reduce
# the infinite-dimensional process based models to finite, albeit high,
# dimensional ones. Inference can then be based on Monte Carlo methods. As
# highlights, specific to BNS we show that an OU process driven by an infinite
# activity Gamma process, that is an OU-$\Gamma$, exhibits unique features which
# allows one to exactly sample from relevant joint distributions. We show that
# this is a consequence of the OU structure and the unique calculus of Gamma and
# Dirichlet processes. Owing to another connection between Gamma/Dirichlet
# processes and the theory of Generalized Gamma Convolutions (GGC) we identify a
# large class of models, we call (FGGC), where one can perfectly sample marginal
# distributions relevant to option pricing and Monte Carlo likelihood analysis.
# This involves a curious result, we establish as Theorem 6.1. We also discuss
# analytic techniques and candidate densities for Monte-Carlo procedures which
# apply more generally.

# %% [markdown]
# ### Default Parameters

# %%
X_train, X_test, y_train, y_test = train_test_split(df["Text"], df["Primary Category"], test_size=0.3, random_state=42)

pipe = Pipeline(
    [
        ("tfidf", TfidfVectorizer()),
        ("clf", LinearSVC(dual="auto", random_state=42, max_iter=5000))
    ]
)

# %%
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print(classification_report(y_test, y_pred))
print(f"Weighted F1-Score: {f1_score(y_test, y_pred, average='weighted')}")
# Out:
#               precision    recall  f1-score   support
#
#      stat.AP       0.63      0.57      0.60      2674
#      stat.CO       0.56      0.42      0.48      1009
#      stat.ME       0.63      0.66      0.64      5544
#      stat.ML       0.77      0.80      0.79      4755
#      stat.TH       0.71      0.72      0.71      4245
#
#     accuracy                           0.68     18227
#    macro avg       0.66      0.63      0.65     18227
# weighted avg       0.68      0.68      0.68     18227
#
# Weighted F1-Score: 0.681991560210697

# %% [markdown]
# ### Grid Search

# %%
param_grid = {
    "tfidf__stop_words": ["english", None],
    "clf__C": [0.05, 0.075, 0.1, 0.25, 0.5],
}

grid = GridSearchCV(pipe, param_grid, cv=5, verbose=3, scoring="f1_weighted")
grid.fit(X_train, y_train)
print(grid.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END clf__C=0.05, tfidf__stop_words=english;, score=0.685 total time=   5.8s
# [CV 2/5] END clf__C=0.05, tfidf__stop_words=english;, score=0.693 total time=   5.8s
# [CV 3/5] END clf__C=0.05, tfidf__stop_words=english;, score=0.688 total time=   5.7s
# [CV 4/5] END clf__C=0.05, tfidf__stop_words=english;, score=0.686 total time=   6.0s
# [CV 5/5] END clf__C=0.05, tfidf__stop_words=english;, score=0.690 total time=   5.7s
# [CV 1/5] END clf__C=0.05, tfidf__stop_words=None;, score=0.686 total time=   6.0s
# [CV 2/5] END clf__C=0.05, tfidf__stop_words=None;, score=0.692 total time=   5.9s
# [CV 3/5] END clf__C=0.05, tfidf__stop_words=None;, score=0.688 total time=   6.2s
# [CV 4/5] END clf__C=0.05, tfidf__stop_words=None;, score=0.684 total time=   6.2s
# [CV 5/5] END clf__C=0.05, tfidf__stop_words=None;, score=0.687 total time=   6.1s
# [CV 1/5] END clf__C=0.075, tfidf__stop_words=english;, score=0.691 total time=   5.7s
# [CV 2/5] END clf__C=0.075, tfidf__stop_words=english;, score=0.695 total time=   5.7s
# [CV 3/5] END clf__C=0.075, tfidf__stop_words=english;, score=0.692 total time=   5.7s
# [CV 4/5] END clf__C=0.075, tfidf__stop_words=english;, score=0.689 total time=   5.8s
# [CV 5/5] END clf__C=0.075, tfidf__stop_words=english;, score=0.693 total time=   5.6s
# [CV 1/5] END clf__C=0.075, tfidf__stop_words=None;, score=0.692 total time=   6.2s
# [CV 2/5] END clf__C=0.075, tfidf__stop_words=None;, score=0.696 total time=   6.1s
# [CV 3/5] END clf__C=0.075, tfidf__stop_words=None;, score=0.692 total time=   6.0s
# [CV 4/5] END clf__C=0.075, tfidf__stop_words=None;, score=0.686 total time=   6.3s
# [CV 5/5] END clf__C=0.075, tfidf__stop_words=None;, score=0.691 total time=   6.4s
# [CV 1/5] END clf__C=0.1, tfidf__stop_words=english;, score=0.692 total time=   5.6s
# [CV 2/5] END clf__C=0.1, tfidf__stop_words=english;, score=0.695 total time=   5.5s
# [CV 3/5] END clf__C=0.1, tfidf__stop_words=english;, score=0.693 total time=   5.4s
# [CV 4/5] END clf__C=0.1, tfidf__stop_words=english;, score=0.689 total time=   5.5s
# [CV 5/5] END clf__C=0.1, tfidf__stop_words=english;, score=0.692 total time=   5.4s
# [CV 1/5] END clf__C=0.1, tfidf__stop_words=None;, score=0.693 total time=   5.9s
# [CV 2/5] END clf__C=0.1, tfidf__stop_words=None;, score=0.697 total time=   6.0s
# [CV 3/5] END clf__C=0.1, tfidf__stop_words=None;, score=0.695 total time=   6.0s
# [CV 4/5] END clf__C=0.1, tfidf__stop_words=None;, score=0.689 total time=   6.2s
# [CV 5/5] END clf__C=0.1, tfidf__stop_words=None;, score=0.693 total time=   6.3s
# [CV 1/5] END clf__C=0.25, tfidf__stop_words=english;, score=0.691 total time=   5.8s
# [CV 2/5] END clf__C=0.25, tfidf__stop_words=english;, score=0.690 total time=   5.7s
# [CV 3/5] END clf__C=0.25, tfidf__stop_words=english;, score=0.690 total time=   6.0s
# [CV 4/5] END clf__C=0.25, tfidf__stop_words=english;, score=0.687 total time=   6.1s
# [CV 5/5] END clf__C=0.25, tfidf__stop_words=english;, score=0.691 total time=   5.9s
# [CV 1/5] END clf__C=0.25, tfidf__stop_words=None;, score=0.694 total time=   6.6s
# [CV 2/5] END clf__C=0.25, tfidf__stop_words=None;, score=0.693 total time=   6.5s
# [CV 3/5] END clf__C=0.25, tfidf__stop_words=None;, score=0.693 total time=   6.0s
# [CV 4/5] END clf__C=0.25, tfidf__stop_words=None;, score=0.689 total time=   6.0s
# [CV 5/5] END clf__C=0.25, tfidf__stop_words=None;, score=0.690 total time=   7.1s
# [CV 1/5] END clf__C=0.5, tfidf__stop_words=english;, score=0.686 total time=   6.1s
# [CV 2/5] END clf__C=0.5, tfidf__stop_words=english;, score=0.683 total time=   6.3s
# [CV 3/5] END clf__C=0.5, tfidf__stop_words=english;, score=0.686 total time=   6.3s
# [CV 4/5] END clf__C=0.5, tfidf__stop_words=english;, score=0.684 total time=   6.1s
# [CV 5/5] END clf__C=0.5, tfidf__stop_words=english;, score=0.683 total time=   6.2s
# [CV 1/5] END clf__C=0.5, tfidf__stop_words=None;, score=0.691 total time=   6.7s
# [CV 2/5] END clf__C=0.5, tfidf__stop_words=None;, score=0.685 total time=   6.6s
# [CV 3/5] END clf__C=0.5, tfidf__stop_words=None;, score=0.689 total time=   6.6s
# [CV 4/5] END clf__C=0.5, tfidf__stop_words=None;, score=0.685 total time=   6.7s
# [CV 5/5] END clf__C=0.5, tfidf__stop_words=None;, score=0.683 total time=   6.7s
# {'clf__C': 0.1, 'tfidf__stop_words': None}

# %%
y_pred = grid.predict(X_test)

print(classification_report(y_test, y_pred))
print(f"Weighted F1-Score: {f1_score(y_test, y_pred, average='weighted')}")
# Out:
#               precision    recall  f1-score   support
#
#      stat.AP       0.69      0.57      0.62      2674
#      stat.CO       0.61      0.38      0.47      1009
#      stat.ME       0.64      0.70      0.67      5544
#      stat.ML       0.78      0.82      0.80      4755
#      stat.TH       0.72      0.74      0.73      4245
#
#     accuracy                           0.70     18227
#    macro avg       0.69      0.64      0.66     18227
# weighted avg       0.70      0.70      0.70     18227
#
# Weighted F1-Score: 0.6984403783457029
